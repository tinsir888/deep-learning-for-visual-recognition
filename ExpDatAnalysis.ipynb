# %% [markdown]
# # Experiment on different patch size

# %%
import re
import numpy as np
def extract_data(log_line):
    # Use regular expressions to extract relevant information
    epoch_match = re.search(r'Epoch (\d+)', log_line)
    train_loss_match = re.search(r'Train Loss: ([0-9.]+)', log_line)
    val_loss_match = re.search(r'Validation Loss: ([0-9.]+)', log_line)
    val_acc_match = re.search(r'Validation Accuracy: ([0-9.]+)', log_line)

    # Extract values from the matches
    epoch = int(epoch_match.group(1)) if epoch_match else None
    train_loss = float(train_loss_match.group(1)) if train_loss_match else None
    val_loss = float(val_loss_match.group(1)) if val_loss_match else None
    val_acc = float(val_acc_match.group(1)) if val_acc_match else None

    return epoch, train_loss, val_loss, val_acc

# Read data from a text file
file_path = './expdata/p56.txt'  # replace with the actual path to your file
data_arrays = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

with open(file_path, 'r') as file:
    for line in file:
        epoch, train_loss, val_loss, val_acc = extract_data(line)
        if epoch is not None:
            data_arrays['epoch'].append(epoch)
            data_arrays['train_loss'].append(train_loss)
            data_arrays['val_loss'].append(val_loss)
            data_arrays['val_acc'].append(val_acc)

# Example: Print the extracted data
#for key, values in data_arrays.items():
    #print(f"{key}: {values}")
#print(for item in data_arrays['train_loss'])
for i in range(1,100,2):
    print(data_arrays['val_acc'][i],',',end='')
# Out:
# 0.048666666666666664 ,0.16566666666666666 ,0.17566666666666667 ,0.2613333333333333 ,0.25566666666666665 ,0.3016666666666667 ,0.32666666666666666 ,0.315 ,0.32233333333333336 ,0.36133333333333334 ,0.338 ,0.35733333333333334 ,0.3536666666666667 ,0.36866666666666664 ,0.366 ,0.38233333333333336 ,0.39866666666666667 ,0.364 ,0.395 ,0.39566666666666667 ,0.36833333333333335 ,0.4066666666666667 ,0.416 ,0.38966666666666666 ,0.406 ,0.3963333333333333 ,0.411 ,0.4066666666666667 ,0.409 ,0.412 ,0.4176666666666667 ,0.41933333333333334 ,0.424 ,0.43366666666666664 ,0.41133333333333333 ,0.43133333333333335 ,0.44466666666666665 ,0.4146666666666667 ,0.42766666666666664 ,0.43833333333333335 ,0.43033333333333335 ,0.4563333333333333 ,0.44866666666666666 ,0.40066666666666667 ,0.44266666666666665 ,0.4503333333333333 ,0.45266666666666666 ,0.43466666666666665 ,0.44433333333333336 ,0.413 ,

# %%
import matplotlib.pyplot as plt

# %%
#patch size = 8:
train_loss_8 = [2.1806350158432783, 1.6006073072805242, 1.3169574242527202, 1.0789132183891232, 0.8987104882628231, 0.7602420479564344, 0.6334915648577577, 0.5288639707585513, 0.4276202390507116, 0.3431972245038566, 0.2770660063725407, 0.22463698161102957, 0.19175355215320142, 0.1112098405611212, 0.08604167717493187, 0.06647169692599672, 0.059384353222104454, 0.028361816132851575, 0.025849821882606563, 0.012353586372366901, 0.006156564473127157, 0.004797719453532501, 0.0022671447851758263, 0.0018394867972455035, 0.0016072407045196425, 0.0013512400012479116, 0.0011779133914141143, 0.0010491526015773732, 0.0009380226991320881, 0.0008449432833743739, 0.0007627557117641919, 0.0006888381021010484, 0.0006240646508265823, 0.0005683358968334209, 0.0005155430233078393, 0.00046974098555530594, 0.00042851650160027004, 0.00039112357219475935, 0.0003585569472723025, 0.00032825312999933484, 0.0003005926231153199, 0.00027620282122308896, 0.00025375323987692215, 0.00023320336629818116, 0.00021481924390388747, 0.000197034212267342, 0.00018082142073041522, 0.00016603924573785862, 0.0001536028693238731, 0.0001406766625562233] 

554 ,1.7030315573016803 ,1.6708310792843502 ,1.660432606935501 ,1.6503981997569401 ,1.6691226239005725 ,1.6430654774109523 ,1.631712647775809 ,1.6602330729365349 ,1.6581966703136761 ,1.6279173716902733 ,1.647158329685529 ,1.6034688353538513 ,1.6029560243089993 ,1.7174610247214634 ,1.6190584438542526 ,1.592802199224631 ,1.601188230017821 ,1.6541307953496773 ,1.6662351066867511 ,1.7358559258282185]

validation_acc_56=[0.048666666666666664 ,0.16566666666666666 ,0.17566666666666667 ,0.2613333333333333 ,0.25566666666666665 ,0.3016666666666667 ,0.32666666666666666 ,0.315 ,0.32233333333333336 ,0.36133333333333334 ,0.338 ,0.35733333333333334 ,0.3536666666666667 ,0.36866666666666664 ,0.366 ,0.38233333333333336 ,0.39866666666666667 ,0.364 ,0.395 ,0.39566666666666667 ,0.36833333333333335 ,0.4066666666666667 ,0.416 ,0.38966666666666666 ,0.406 ,0.3963333333333333 ,0.411 ,0.4066666666666667 ,0.409 ,0.412 ,0.4176666666666667 ,0.41933333333333334 ,0.424 ,0.43366666666666664 ,0.41133333333333333 ,0.43133333333333335 ,0.44466666666666665 ,0.4146666666666667 ,0.42766666666666664 ,0.43833333333333335 ,0.43033333333333335 ,0.4563333333333333 ,0.44866666666666666 ,0.40066666666666667 ,0.44266666666666665 ,0.4503333333333333 ,0.45266666666666666 ,0.43466666666666665 ,0.44433333333333336 ,0.413]

# %% [markdown]
# ## Experiment data for training process

# %%
# Sample data for each subplot
types = ['path size=8', 'patch size=14', 'patch size=28', 'patch size=32', 'patch size=56']
num_epochs = len(train_loss_8)  # Replace with your actual number of epochs
#train_loss_14 = np.random.rand(num_epochs)  # Replace with your actual data
#validation_loss_14 = np.random.rand(num_epochs)  # Replace with your actual data

# Set up the positions for the bars
x = np.arange(len(types))
width = 0.35  # Width of the bars

# Create a 1x5 grid of subplots
fig, axs = plt.subplots(1, 5, figsize=(15, 3))  # Adjust the figsize as needed

# Plotting for each subplot
i=0
axs[i].plot(range(num_epochs), train_loss_8, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_8, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_14, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_14, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_28, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_28, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_32, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_32, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_56, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_56, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
# Adjust layout to prevent clipping of titles and labels
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for each subplot
types = ['path size=8', 'patch size=14', 'patch size=28', 'patch size=32', 'patch size=56']
#train_loss_14 = np.random.rand(num_epochs)
#validation_loss_14 = np.random.rand(num_epochs)

# Create a 2x3 grid of subplots
fig, axs = plt.subplots(2, 3, figsize=(15, 8))  # Adjust the figsize as needed

# Flatten the axs array to iterate over subplots
axs = axs.flatten()

# Plotting for each subplot
i=0
axs[i].plot(range(num_epochs), train_loss_8, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_8, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_14, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_14, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_28, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_28, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_32, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_32, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()
i+=1
axs[i].plot(range(num_epochs), train_loss_56, label='Train Loss')
axs[i].plot(range(num_epochs), validation_loss_56, label='Validation Loss')
axs[i].set_title(types[i])
axs[i].set_xlabel('Epoch')
axs[i].set_ylabel('Accuracy')
axs[i].legend()

# Hide the empty subplot in the last position (if needed)
axs[-1].axis('off')

# Adjust layout to prevent clipping of titles and labels
plt.tight_layout()

plt.show()

# %%
# Sample data for each line
num_epochs = len(train_loss_8)  # Replace with your actual number of epochs

# Plotting a single plot with five lines
plt.plot(range(num_epochs), validation_acc_8, label='patch size=8')
plt.plot(range(num_epochs), validation_acc_14, label='patch size=14')
plt.plot(range(num_epochs), validation_acc_28, label='patch size=28')
plt.plot(range(num_epochs), validation_acc_32, label='patch size=32')
plt.plot(range(num_epochs), validation_acc_56, label='patch size=56')

# Add labels, title, and legend
plt.title('Validation accuracy for different patch size')
plt.xlabel('Epoch')
plt.ylabel('Validation accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## Experiment data for evaluating model

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
# Your data
types = ['8', '14', '28', '32', '56']
t_acc = [0.9036666666666666, 0.9256666666666666,0.8356666666666667, 0.781, 0.425]
t_loss =[0.42545741458889097,0.34291515685617924,0.6680032030368844,0.7649105253318945,1.7188709924618404]
# Plotting a bar plot
plt.bar(types, t_acc, color='blue', alpha=0.7)
plt.title('Test accuracy for different patch size')
plt.xlabel('Patch size')
plt.ylabel('Accuracy')
plt.ylim(0, 1)  # Set the y-axis range to [0, 1]
plt.grid(axis='y')

#plt.legend()
plt.subplot(1, 2, 2)
plt.bar(types, t_loss, color='red', alpha=0.7)
plt.title('Test loss for different patch size')
plt.xlabel('Patch size')
plt.ylabel('Loss')
#plt.ylim(0, 1)  # Set the y-axis range to [0, 1]
plt.grid(axis='y')

#plt.legend()
plt.show()

# %% [markdown]
# # Experiment on data argumentation
